# %% [markdown]
# # 9. This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
install.packages("ISLR")

# %%
library(ISLR)

# %%
Auto<-na.omit(Auto)

# %% [markdown]
# ## (a) Which of the predictors are quantitative, and which are qualitative?

# %% [markdown]
# * Quantitative: mpg, cylinders, displacement, horsepower, weight, acceleration, year
# * Qualitative: origin, name

# %% [markdown]
# ## (b) What is the range of each quantitative predictor ?

# %%
sapply(Auto[,c(1:7)],range)
# Out:
#      mpg  cylinders displacement horsepower weight acceleration year
# [1,]  9.0 3          68           46        1613    8.0         70
# [2,] 46.6 8         455          230        5140   24.8         82

# %% [markdown]
# ## (c) What is the mean and standard deviation of each quantitative predictor?

# %% [markdown]
# ### -Mean

# %%
sapply(Auto[,c(1:7)],mean)
# Out:
#          mpg    cylinders displacement   horsepower       weight acceleration
#    23.445918     5.471939   194.411990   104.469388  2977.584184    15.541327
#         year
#    75.979592

# %% [markdown]
# ### -Standard Deviation

# %%
sapply(Auto[,c(1:7)],sd)
# Out:
#          mpg    cylinders displacement   horsepower       weight acceleration
#     7.805007     1.705783   104.644004    38.491160   849.402560     2.758864
#         year
#     3.683737

# %% [markdown]
# ## (d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
Auto_RM <- Auto[-c(10:84),]

# %% [markdown]
# ### -Range

# %%
sapply(Auto_RM[,c(1:7)],range)
# Out:
#      mpg  cylinders displacement horsepower weight acceleration year
# [1,] 11.0 3          68           46        1649    8.5         70
# [2,] 46.6 8         455          230        4997   24.8         82

# %% [markdown]
# ### -Mean

# %%
sapply(Auto_RM[,c(1:7)],mean)
# Out:
#          mpg    cylinders displacement   horsepower       weight acceleration
#    24.368454     5.381703   187.753943   100.955836  2939.643533    15.718297
#         year
#    77.132492

# %% [markdown]
# ### -Standard Deviation

# %%
sapply(Auto_RM[,c(1:7)],sd)

# %% [markdown]
# ## (e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your ﬁndings.

# %%
pairs(Auto)
# Out:
# plot without title

# %% [markdown]
# ### 1. displacement, horsepower and weight are having similar correlation with MPG
# ### 2. MPG is having positive correlation with year: MPG grows among the past years
# ### 3. cylinders is having categorical effect on other factors only except origin
# ### 4. origin is having average categorical effect on

# %% [markdown]
# ## (f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.

# %% [markdown]
# ### -displacement, horsepower and weight are having similar correlation with MPG

# %%
sub <- Auto[,c(1:5)]
sub <- sub[,-c(2)]
pairs(sub)
# Out:
# plot without title

# %% [markdown]
# ### -So pick one out of those three is having similar result as pickall - pick weight
# ### -acceleration and name is not having clear correlation with MPG -do not pick acceleration and name
# ### -cylinders and origin is having different categorical effect on MPG- pick cylinders and origin
# ### MPG predictors would be: cylinders, weight,year and origin
